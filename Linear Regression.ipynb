# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
RiceDataset=pd.read_excel('Rice_MSC_Dataset.xlsx')
RiceDataset.head()
# Out:
#    AREA  PERIMETER  MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY   EQDIASQ  SOLIDITY  \
# 0  7805    437.915    209.8215     48.0221        0.9735   99.6877    0.9775
# 1  7503    340.757    138.3361     69.8417        0.8632   97.7400    0.9660
# 2  5124    314.617    141.9803     46.5784        0.9447   80.7718    0.9721
# 3  7990    437.085    201.4386     51.2245        0.9671  100.8622    0.9659
# 4  7433    342.893    140.3350     68.3927        0.8732   97.2830    0.9831
#
#    CONVEX_AREA  EXTENT  ASPECT_RATIO  ...  ALLdaub4L  ALLdaub4a  ALLdaub4b  \
# 0         7985  0.3547        4.3693  ...   113.9924    65.0610    59.5989
# 1         7767  0.6637        1.9807  ...   105.7055    64.3685    62.2084
# 2         5271  0.4760        3.0482  ...   109.7155    62.6423    58.7439
# 3         8272  0.6274        3.9325  ...   116.5405    64.9069    60.2562
# 4         7561  0.6006        2.0519  ...   107.7502    64.7071    61.3549
#
# ...

# %%
RiceDataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75000 entries, 0 to 74999
# Columns: 107 entries, AREA to CLASS
# dtypes: float64(95), int64(11), object(1)
# memory usage: 61.2+ MB

# %%
RiceDataset.columns
# Out:
# Index(['AREA', 'PERIMETER', 'MAJOR_AXIS', 'MINOR_AXIS', 'ECCENTRICITY',
#        'EQDIASQ', 'SOLIDITY', 'CONVEX_AREA', 'EXTENT', 'ASPECT_RATIO',
#        ...
#        'ALLdaub4L', 'ALLdaub4a', 'ALLdaub4b', 'ALLdaub4Y', 'ALLdaub4Cb',
#        'ALLdaub4Cr', 'ALLdaub4XX', 'ALLdaub4YY', 'ALLdaub4ZZ', 'CLASS'],
#       dtype='object', length=107)

# %%
df = RiceDataset[['AREA', 'PERIMETER', 'MAJOR_AXIS', 'MINOR_AXIS', 'ECCENTRICITY', 'CLASS']]

# %%
df
# Out:
#         AREA  PERIMETER  MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY      CLASS
# 0       7805    437.915    209.8215     48.0221        0.9735    Basmati
# 1       7503    340.757    138.3361     69.8417        0.8632    Arborio
# 2       5124    314.617    141.9803     46.5784        0.9447    Jasmine
# 3       7990    437.085    201.4386     51.2245        0.9671    Basmati
# 4       7433    342.893    140.3350     68.3927        0.8732    Arborio
# ...      ...        ...         ...         ...           ...        ...
# 74995   5551    285.911    114.1695     62.9079        0.8345    Arborio
# 74996   7696    322.703    121.3900     81.1375        0.7438  Karacadag
# 74997   7579    339.295    136.3125     71.2866        0.8524    Arborio
# 74998  15174    489.502    200.9486     97.6282        0.8740     Ipsala
# 74999  12931    452.635    185.5138     90.2651        0.8736     Ipsala
#
# [75000 rows x 6 columns]

# %%
RiceDataset.describe()
# Out:
#                AREA     PERIMETER    MAJOR_AXIS    MINOR_AXIS  ECCENTRICITY  \
# count  75000.000000  75000.000000  75000.000000  75000.000000  75000.000000
# mean    8379.197507    378.169453    161.805540     66.829335      0.886077
# std     3119.209274     70.597008     36.461005     16.689269      0.071906
# min     3929.000000    261.040000     96.968300     34.673000      0.627700
# 25%     6259.000000    316.431500    132.623500     49.650200      0.846100
# 50%     7345.000000    351.261000    149.343950     69.183900      0.885600
# 75%     8901.000000    444.986000    197.462025     75.814125      0.950800
# max    21019.000000    593.698000    255.647200    113.441100      0.986800
#
#             EQDIASQ      SOLIDITY   CONVEX_AREA        EXTENT  ASPECT_RATIO  \
# count  75000.000000  75000.000000  75000.000000  75000.000000  75000.000000
# mean     101.731251      0.975896   8584.862320      0.633226      2.597063
# ...

# %%
sns.pairplot(df)

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
sns.histplot(RiceDataset['AREA'])
# Out:
# <AxesSubplot:xlabel='AREA', ylabel='Count'>

# %%
sns.histplot(RiceDataset['PERIMETER'])
# Out:
# <AxesSubplot:xlabel='PERIMETER', ylabel='Count'>

# %%
X = df[['AREA', 'PERIMETER', 'MAJOR_AXIS', 'MINOR_AXIS', 'ECCENTRICITY']]
y = df['AREA']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
# print the intercept
print(lm.intercept_)
# Out:
# -3.637978807091713e-12

# %%
coeff_df = pd.DataFrame(lm.coef_,X.columns,columns=['Coefficient'])
coeff_df
# Out:
#                Coefficient
# AREA          1.000000e+00
# PERIMETER     2.421341e-16
# MAJOR_AXIS   -3.353168e-16
# MINOR_AXIS   -9.135354e-16
# ECCENTRICITY -1.711172e-13

# %%
predictions = lm.predict(X_test)

# %%
plt.scatter(y_test,predictions)

# %%
sns.distplot((y_test-predictions),bins=50)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='AREA', ylabel='Density'>

# %%
from sklearn import metrics

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 1.0006867038706939e-12
# MSE: 2.0628046297933504e-24
# RMSE: 1.4362467161993272e-12
